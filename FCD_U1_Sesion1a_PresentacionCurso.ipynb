# %% [markdown]
# <img src="Local\imgs\U1\Banner_FCD.jpg" alt="banner" width="1100"  height="180">

# %% [markdown]
# # <span style="color:black;"><strong> 📘 Presentación del curso y objetivos de aprendizaje</strong></span>
# ---
# <p align="right">
#   <a href="https://colab.research.google.com/github/usuario/repositorio/blob/main/ruta/al/notebook.ipynb" target="_blank">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir en Colab"/>
#   </a>
# </p>
#
# ## <span style="color:gray;"><strong>🎯 Objetivos de la temática</strong></span>
#
# > 📘 Conocer los **propósitos y la estructura general** del curso.
# >
# > 📊 Acordar los **porcentajes y criterios de evaluación** para las distintas actividades.
# >
# > 📂 Definir el **método de entrega** y organización de las actividades evaluativas a lo largo del curso.

# %% [markdown]
# ## <span style="color:#2F749F;"><strong> 📚 Unidades del curso</strong></span>
# <img src="Local\imgs\U1\unidades_curso.png" alt="unidades" width="1000"  height="500">

# %% [markdown]
# ## 🗓️ **Programación de clases y actividades evaluativas**
# La programación completa del curso, que incluye la distribución de contenidos por unidad, las clases programadas, actividades clave y tipos de evaluación, está disponible en el archivo [Programación PDF](Local\file\Programacion_FCD_2025-02.pdf). Allí podrás consultar qué se trabaja cada semana y cómo se evalúa cada componente.
#
# > 👉 Revisa el cronograma para planificar tu participación, preparar tus entregas y seguir el ritmo del curso de forma clara y
# organizada.
#
# <img src="Local\imgs\U1\evaluacion_curso.png" alt="evaluacion" width="1000"  height="500">
#
# ### 📥 **Entrega de trabajos**
# Todas las actividades, entregables y proyectos del curso deben ser gestionados a través del repositorio de **`GitHub`** creado por cada estudiante. Este repositorio será el único canal oficial para la entrega de trabajos, permitiendo llevar un control ordenado, transparente y colaborativo del proceso formativo. Asegúrate de mantener tu repositorio actualizado y documentación adecuada (README, carpetas organizadas, comentarios en el código, etc.). Las fechas límite están definidas en el cronograma y el historial de Git será considerado parte de la evaluación.
#
# > No olvides que, como estudiante de la Universidad de Antioquia, tienes acceso a los beneficios de **`GitHub Education`**. He preparado una guía que puedes consultar en el archivo [GibHub-UdeA PDF](Local\file\GibHub-UdeA.pdf).
#
# #### 🗂️ **Estructura del repositorio:**
#
# 📁 nombre-del-repositorio/
# │
# <br> ├── 📁 articulo/
# <br> │   ├── informe_1_nombre_proyecto.pdf
# <br> │   ├── informe_XX_nombre_proyecto.pdf
# <br> │   └── informe_final_nombre_proyecto.pdf
# <br> │
# <br> ├── 📁 proyecto_aula/
# <br> │   ├── py_nombre_proyecto_01_intro.ipynb
# <br> │   ├── py_nombre_proyecto_02_limpieza.ipynb
# <br> │   └── py_nombre_proyecto_XX_nombre.ipynb
# <br> │
# <br> ├── 📁 sesiones_practicas/
# <br> │   ├── sc_1_nombre_sesion.ipynb
# <br> │   ├── sc_2_nombre_sesion.ipynb
# <br> │   └── sc_XX_nombre_sesion.ipynb
# <br> │
# <br> ├── 📁 datos/
# <br> │   └── dataset_procesado.csv
# <br> │
# <br> ├── 📁 recursos/
# <br> │   └── referencias_bibliograficas.pdf
# <br> │
# <br> └── README.md
#
# #### 📝 **Indicaciones adicionales:**
# - Sigue las indicaciones para los  **nombres** de archivos y carpetas.
#   Ejemplo: `informe_final_nombre_proyecto.pdf`, `sc_1_nombre_sesion.ipynb`
#
# - El archivo `README.md` debe incluir:
#   - Descripción general del proyecto
#   - Instrucciones para ejecutar los notebooks
#   - Nombres y correos del estudiante
#   - Dependencias o librerías requeridas
#
# - Asegúrate de que los notebooks estén:
#   - ✅ Completamente ejecutados (todas las celdas con salida)
#   - ✅ Limpios (sin errores intermedios)
#   - ✅ Comentados y organizados
#
# - **Evita subir archivos innecesarios**, como:
#   - Archivos temporales (`.ipynb_checkpoints/`)
#   - Bases de datos pesadas (si no son estrictamente necesarias)
#   - Versiones duplicadas sin explicación
#
# > 📌 Seguir estas indicaciones facilitará la revisión, garantizará una retroalimentación más ágil y evitará penalizaciones por desorganización.
#
#
# ### 🐙 **Formulario para reportar tu repositorio:**
# Reporta tu repositorio en el siguiente formulario, solo sí, ya cumple con la estructura indicada: [Formulario](https://docs.google.com/forms/d/e/1FAIpQLSdHdk4OF2K1CmAqZtEVpzJbMe7kqdStHvcGtq3fM9BHODvRgQ/viewform?usp=preview).

# %% [markdown]
# ### 📝 **Formulario de Conocimientos Previos**
#
# Por favor completa este [Formulario](https://docs.google.com/forms/d/e/1FAIpQLSfwlB7QT0Cmpy8Dtvputp8CJZdYt8QMTdyLGAZf4ogtuj6ClQ/viewform?usp=header) para conocer tu punto de partida en el curso.  Las respuestas nos ayudarán a identificar fortalezas y aspectos por reforzar.

# %% [markdown]
# ---
#
# <div style="text-align:center; color:#607D8B; font-weight:bold; font-size:14px;">
# “Sin datos, solo eres otra persona con una opinión.” – W. Edwards Deming
# </div>
