# %% [markdown]
# <img src="Local\imgs\U1\banner_fcd.jpg" alt="banner" width="1100"  height="150">

# %% [markdown]
# # <span style="color:black;"><strong>Ética en la Toma de Decisiones Basada en Datos</strong></span>
# ---
# <p align="right">
#   <a href="https://colab.research.google.com/github/mariabda2/intro_data_2026/blob/main/FCD_U1_3_Etica_en_los_datos.ipynb?clone=true" target="_blank">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir en Colab"/>
#   </a>
# </p>
#
#
# ## <span style="color:#2F749F;"><strong>🎯 Objetivos de aprendizaje</strong></span>
#
# > ✅ Comprender los **principios éticos** que deben guiar la toma de decisiones basada en datos.
# >
# > ✅ Reconocer y mitigar **sesgos y riesgos** en modelos y procesos analíticos.
# >
# > ✅ Evaluar el impacto de las decisiones basadas en datos en **personas, comunidades y organizaciones**.
# >
# > ✅ Aplicar prácticas de **transparencia, privacidad y responsabilidad** en proyectos de ciencia de datos.

# %% [markdown]
# ## <span style="color:#2F749F;"><strong>1. Principios éticos transversales</strong></span>
#
# Estos marcos se sustentan en principios comunes que deben guiar el uso **ético y responsable** de los datos:
#
# - <span style="color:#4CAF50;">**✔ Consentimiento informado**</span>: La recolección de datos debe basarse en el consentimiento libre, informado y explícito del titular.
# - <span style="color:#2196F3;">**✔ Transparencia y trazabilidad**</span>: Las personas deben conocer qué datos se recopilan, su finalidad, uso y tiempo de conservación.
# - <span style="color:#FFC107;">**✔ Minimización y proporcionalidad**</span>: Recoger únicamente los datos estrictamente necesarios para el objetivo declarado.
# - <span style="color:#FF9800;">**✔ Limitación de finalidad**</span>: Prohibición de usar los datos para fines distintos a los autorizados.
# - <span style="color:#9C27B0;">**✔ Seguridad y confidencialidad**</span>: Proteger la información contra accesos no autorizados, pérdidas o alteraciones indebidas.
# - <span style="color:#E91E63;">**✔ No discriminación y justicia algorítmica**</span>: Evitar que los sistemas predictivos refuercen sesgos o exclusiones sociales.

# %% [markdown]
# ## <span style="color:#2F749F;"><strong>2. Buenas prácticas para el cumplimiento ético-normativo</strong></span>
#
# - **Privacy by Design** → Integrar la privacidad desde la fase inicial del proyecto, no como añadido posterior.
# - **Evaluaciones de Impacto (DPIA)** → Analizar riesgos para la privacidad antes de implementar soluciones.
# - **Documentación y trazabilidad** → Mantener un registro claro de cómo, dónde y por qué se usan los datos.
# - **Protecciones técnicas** → Aplicar *seudonimización*, *differential privacy* y control de acceso granular.
# - **Gobernanza ética** → Establecer auditorías y comités de revisión multidisciplinarios.
# - **Empoderamiento del usuario** → Ofrecer herramientas para que consulten, modifiquen o eliminen sus datos.

# %% [markdown]
# ## <span style="color:#2F749F;"><strong>3. 🎯 Sesgo (bias) </strong></span>
#
# <p align="center">
#   <img src="Local\imgs\U1\bias.png" alt="bias" width="200"  height="200"/>
# </p>
#
# Un **sesgo** se refiere a una distorsión sistemática en la recolección, análisis, interpretación o modelado de datos. Puede ser introducido en varias etapas del ciclo de vida del dato y del modelo.
#
# > 📌 En modelos de aprendizaje automático, el sesgo ocurre cuando las predicciones tienden a desviarse consistentemente del valor real, como si el modelo estuviera “apuntando mal”.

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>3.1. Tipos de sesgo </strong></span>
#
# <p align="center">
#   <img src="Local\imgs\U1\tipos_sesgo.png" alt="tipos-sesgo" width="1000"  height="800"/>
# </p>

# %% [markdown]
# #### <span style="color:#2F749F;"><strong>3.1.1. Muestreo (Sampling Bias) </strong></span>
#
# <p align="center">
#   <img src="Local\imgs\U1\sampling-bias.png" alt="sampling-bias" width="600"  height="500"/>
# </p>
#
# Este sesgo ocurre cuando el procedimiento de selección de datos introduce una **representación no equilibrada** de la población objetivo, lo que puede derivar en estimaciones distorsionadas y conclusiones erróneas. Este sesgo surge típicamente por la exclusión sistemática de ciertos subgrupos o la sobrerrepresentación de otros debido a métodos de recolección no aleatorios o mal diseñados.
#
# Por ejemplo, encuestas realizadas únicamente en entornos urbanos podrían subestimar las perspectivas de poblaciones rurales, generando una falta de validez externa.
#
# Minimizar este sesgo requiere un diseño muestral representativo y estrategias de estratificación o aleatorización adecuadas ([Bethlehem, 2010](https://doi.org/10.1111/j.1751-5823.2010.00112.x); [Lohr, 2021](https://doi.org/10.1201/9781003223713)).
#
# > **Ejemplo:** Un modelo predictivo entrenado únicamente con datos de adultos urbanos puede fallar al aplicarse en adolescentes, ya que sus patrones de comportamiento y contexto son distintos.

# %% [markdown]
# #### <span style="color:#2F749F;"><strong>3.1.2. Medición (Measurement Bias) </strong></span>
#
# <p align="center">
#   <img src="Local\imgs\U1\measurement_bias.jpg" alt="measurement_bias" width="1000"  height="500"/>
# </p>
#
# Imagen tomada de [cut-the-saas.com](https://www.cut-the-saas.com/learn-prompting-ai-bias).
#
# Es un error sistemático que ocurre cuando los datos recopilados **no representan con precisión** la realidad que se pretende medir. Este sesgo puede surgir por fallas en los instrumentos de medición, inconsistencias en los procedimientos de recolección, condiciones inadecuadas de observación o definiciones imprecisas de las variables.
#
# A diferencia del error aleatorio, el measurement bias desplaza consistentemente las mediciones en una dirección, lo que puede comprometer la validez interna y externa de un estudio.
#
# En el contexto de ciencia de datos y aprendizaje automático, este sesgo puede introducir distorsiones en la fase de entrenamiento, generando modelos menos precisos o incluso discriminatorios ([Fowler, 2014](https://uk.sagepub.com/en-gb/eur/survey-research-methods/book239405); [Groves et al., 2009](https://www.wiley.com/en-us/Survey+Methodology%2C+2nd+Edition-p-9780470465462)).
#
# > **Ejemplo:** En medicina, si un dispositivo mide sistemáticamente la presión arterial más baja de lo que realmente es, todos los pacientes podrían ser subestimados en su riesgo cardiovascular, afectando decisiones clínicas basadas en esos datos.

# %% [markdown]
# #### <span style="color:#2F749F;"><strong>3.1.3. Selección (Selection Bias) </strong></span>
#
# <p align="center">
#   <img src="Local\imgs\U1\selection-bias.png" alt="selection-bias" width="800"  height="500"/>
# </p>
#
# El sesgo de selección se presenta cuando la muestra utilizada para entrenar o evaluar un modelo predictivo **no es representativa de la población objetivo**, lo que conduce a estimaciones y predicciones sistemáticamente distorsionadas. Este problema puede surgir en distintas etapas del flujo de datos, como en la recolección, muestreo o filtrado, y se manifiesta en contextos donde ciertos grupos o casos tienen mayor probabilidad de ser incluidos que otros.
#
# En ciencia de datos y aprendizaje automático, este sesgo puede provocar que un modelo generalice de forma deficiente, especialmente cuando se aplica a datos fuera de la distribución con la que fue entrenado ([Hastie, Tibshirani, & Friedman, 2009](https://link.springer.com/book/10.1007/978-0-387-84858-7); [Kohavi et al., 2020](https://link.springer.com/article/10.1007/s10618-008-0114-1)).
#
# > Se distinguen **varios tipos** específicos de sesgo de selección, entre ellos:
# > - Sesgo por muestreo no aleatorio: la muestra se obtiene de manera que excluye sistemáticamente parte de la población.
# >
# > - Sesgo por autoselección: los individuos se incluyen o excluyen según decisiones propias (p. ej., encuestas voluntarias).
# >
# > - Sesgo de supervivencia: se consideran solo los casos que "sobreviven" a cierto filtro temporal o condicional.
# >
# > - Sesgo de atrición: pérdida sistemática de participantes a lo largo del tiempo.
#
# En la práctica, mitigar este sesgo requiere técnicas como muestreo estratificado, ponderación estadística, validación con datos externos y, en contextos de machine learning, el uso de domain adaptation para ajustar modelos a cambios de distribución ([Zhao et al., 2022](https://dl.acm.org/doi/10.1145/3527152)).
#
# La prevención requiere un diseño muestral riguroso, estrategias para maximizar la respuesta y métodos estadísticos que ajusten las diferencias observadas ([Hernán, Hernández-Díaz & Robins, 2004](https://journals.lww.com/epidem/fulltext/2004/09000/a_structural_approach_to_selection_bias.20.aspx); [Delgado-Rodríguez & Llorca, 2004](https://jech.bmj.com/content/58/8/635)).
#
#
# > **Ejemplo:** Evaluar la eficacia de un tratamiento médico solo con pacientes que completaron el tratamiento, ignorando a quienes lo abandonaron, puede sobreestimar su efectividad real.

# %% [markdown]
# #### <span style="color:#2F749F;"><strong>3.1.4. Algorítmico (Algorithmic Bias)</strong></span>
#
#
# <p align="center">
#   <img src="Local\imgs\U1\algorithmic-bias.jpg" alt="algorithmic-bias" width="1000"  height="500"/>
# </p>
#
# Tomado de [alumni.berkeley.edu](https://alumni.berkeley.edu/california-magazine/online/biased-algorithms-exacerbate-racial-inequality-health-care/)
#
# El sesgo algorítmico se refiere a la generación sistemática de **resultados distorsionados** por parte de un sistema de inteligencia artificial o aprendizaje automático, debido a la influencia de prejuicios implícitos presentes en los datos, en el diseño del algoritmo o en las decisiones de modelado. Este fenómeno ocurre incluso cuando los datos aparentan ser neutrales, ya que los algoritmos pueden amplificar y perpetuar desigualdades sociales, históricas o institucionales existentes.
#
# Este tipo de sesgo puede **originarse en diferentes etapas del ciclo de vida del sistema**, incluyendo la selección de variables, la recolección de datos, la definición de objetivos de optimización o el uso de métricas que no capturan adecuadamente la equidad ([Barocas, Hardt & Narayanan, 2023](https://fairmlbook.org/); [Mehrabi et al., 2021](https://dl.acm.org/doi/10.1145/3457607)).
#
# En consecuencia, los sesgos algorítmicos no solo afectan la precisión y la validez de los modelos, sino que también tienen implicaciones éticas y sociales de gran alcance, especialmente en contextos sensibles como la salud, la justicia y el acceso a recursos.
#
# > **Ejemplo:** Un sistema de recomendación de empleo que históricamente ha priorizado candidatos hombres para roles técnicos puede seguir haciéndolo, incluso si las mujeres tienen perfiles equivalentes, perpetuando la discriminación de género.

# %% [markdown]
# #### <span style="color:#2F749F;"><strong>3.1.5. Por retroalimentación (Feedback Loop)</strong></span>
#
# <p align="center">
#   <img src="Local\imgs\U1\realimentacion-bias.png" alt="realimentacion-bias" width="500"  height="500"/>
# </p>
#
#
# Este sesgo se produce cuando **las predicciones** generadas por un modelo **influyen en las decisiones o comportamientos** que, a su vez, afectan los datos que se recopilan posteriormente y que serán utilizados para reentrenar el mismo modelo.
#
# Este ciclo cerrado **puede reforzar y amplificar patrones preexistentes** —incluidos aquellos incorrectos, incompletos o discriminatorios—, provocando que los errores sistemáticos se acumulen con el tiempo.
#
# En contextos como la asignación de recursos, la evaluación de riesgos o los sistemas de recomendación, este fenómeno puede consolidar desigualdades estructurales y reducir la capacidad del modelo para generalizar de manera justa y precisa ([Ensign et al., 2018](https://arxiv.org/abs/1706.09847); [Mehrabi et al., 2021](https://dl.acm.org/doi/10.1145/3457607)).
#
# > **Ejemplo:** Un modelo policial que predice mayor criminalidad en ciertas zonas puede llevar a asignar más patrullas allí. Esto genera más reportes y arrestos en esa área, reforzando la creencia de que hay más criminalidad, aunque no se esté midiendo objetivamente.

# %% [markdown]
# #### <span style="color:#2F749F;"><strong>3.1.6. Resumen de tipos de sesgo</strong></span>
#
# A continuación, se realiza una comparación estructurada de algunos tipos de sesgo identificados en la literatura, considerando su definición, causas comunes, ejemplos prácticos y estrategias de mitigación.
#
# | Tipo de sesgo                             | Definición breve                                                                                                                                                 | Ejemplo sencillo                                                                                                     | Causas principales                                                                                                            | Estrategias de mitigación                                                                                                    |
# | ----------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------- |
# | **Muestreo (Sampling Bias)**              | Sesgo que surge cuando la muestra de datos no representa adecuadamente a la población objetivo, debido a exclusión o sobrerrepresentación sistemática de grupos. | Modelo de salud entrenado solo con datos de adultos urbanos aplicado a población rural adolescente.                  | Selección no aleatoria, subrepresentación de grupos minoritarios, limitaciones geográficas o temporales.                     | Muestreo aleatorio estratificado, aumento de la diversidad de la muestra, técnicas de ponderación.                           |
# | **Medición (Measurement Bias)**           | Ocurre cuando los datos recopilados no reflejan con precisión la realidad, por errores en instrumentos, inconsistencias en recolección o definiciones ambiguas.  | Sensor de temperatura mal calibrado que registra fiebre en pacientes sanos.                                          | Instrumentos defectuosos, protocolos inconsistentes, errores humanos, definiciones vagas.                                    | Calibrar y validar instrumentos, estandarizar procesos de recolección, capacitación del personal.                            |
# | **Selección (Selection Bias)**            | Aparece al incluir o excluir datos de manera que distorsionan las conclusiones, ya sea por criterios explícitos o por disponibilidad limitada de la información. | Estudio de productividad que omite trabajadores remotos, sobreestimando horas presenciales como indicador clave.     | Inclusión o exclusión sesgada, limitaciones de acceso a datos, filtrado intencional o accidental de casos.                   | Ampliar las fuentes de datos, criterios de inclusión claros y transparentes, auditorías periódicas de la base de datos.      |
# | **Algorítmico (Algorithmic Bias)**        | Se produce cuando un modelo reproduce o amplifica desigualdades históricas, sociales o institucionales presentes en los datos o en el diseño del algoritmo.      | Uso del historial de arrestos como predictor de “riesgo”, penalizando más a minorías raciales.                       | Datos de entrenamiento con sesgos históricos, diseño de variables problemáticas, objetivos de optimización no inclusivos.    | Revisión ética de variables, recolección de datos más diversos, ajuste de la función objetivo para promover equidad.         |
# | **Por retroalimentación (Feedback Loop)** | Sesgo en el que las predicciones del modelo afectan los datos futuros que lo alimentan, reforzando patrones iniciales y amplificando errores o desigualdades.    | Sistema policial que asigna más patrullas a zonas “de riesgo” detectadas por el modelo, generando más arrestos allí. | Implementación de modelos en contextos donde sus resultados influyen directamente en las futuras observaciones.               | Monitoreo continuo del impacto, rediseño periódico del modelo, uso de datos externos para romper el ciclo de retroalimentación.|

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>3.2. ¿Cómo detectar sesgos? </strong></span>
#
# Detectar sesgos es un paso esencial para garantizar decisiones automatizadas justas, transparentes y socialmente responsables. A continuación se presentan métodos clave para identificar sesgos en sistemas algorítmicos:
#
# #### <span style="color:#2F749F;"><strong>3.2.1. Exploración inicial de los datos</strong></span>
# - Analiza distribuciones por atributos sensibles como **género**, **raza/etnia**, **edad**, **nivel socioeconómico**, etc.
# - Revisa valores ausentes, codificaciones problemáticas y posibles correlaciones con variables de salida.
# - Visualizaciones recomendadas:
#   - Histogramas comparativos
#   - Gráficos de barras segmentados
#   - Boxplots por grupo
#
# #### <span style="color:#2F749F;"><strong>3.2.2. Comparación de métricas por subgrupos</strong></span>
# - Evalúa el rendimiento del modelo (precisión, recall, F1-score, AUC) por cada grupo demográfico.
# - Identifica disparidades significativas en errores (falsos positivos/negativos) entre subpoblaciones.
# - Aplica métricas de equidad como:
#   - Equal Opportunity
#   - Demographic Parity
#   - Predictive Equality
#
# #### <span style="color:#2F749F;"><strong>3.2.3. Uso de herramientas de auditoría algorítmica</strong></span>
# Estas herramientas permiten auditar, visualizar y mitigar sesgos en sistemas automatizados:
#
# | Herramienta                               | Enlace                                                                                      | Características Principales                                                                                  | Compatible con...                          |
# |-------------------------------------------|---------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------|--------------------------------------------|
# | **Fairness Indicators (Google)**          | [🔗 Repositorio GitHub](https://github.com/tensorflow/fairness-indicators)                             | Métricas visuales para modelos de clasificación y comparación entre subgrupos.                              | TensorFlow                                 |
# | **Aequitas**                               | [🔗 Repositorio GitHub](https://github.com/dssg/aequitas)                                               | Auditoría ética, con reportes claros sobre disparidades por atributos sensibles.                            | Python, modelos personalizados             |
# | **AI Fairness 360 (IBM)**                 | [🔗 Repositorio GitHub](https://github.com/Trusted-AI/AIF360)                                           | Métricas + algoritmos para mitigar sesgos antes, durante y después del modelado.                            | Python, scikit-learn, TensorFlow           |
# | **What-If Tool**                          | [🔗 Página Web](https://pair-code.github.io/what-if-tool/)                                         | Interfaz visual para modificar datos y analizar impacto en las predicciones sin escribir código.            | TensorFlow SavedModel, Cloud AI Platform   |
# | **Fairlearn**                             | [🔗 Repositorio GitHub](https://github.com/fairlearn/fairlearn)                                         | Técnicas de mitigación + gráficos para análisis de equidad y disparidad en modelos.                         | scikit-learn, Jupyter Notebooks            |
# | **EthicalML**                             | [🔗 Repositorio GitHub](https://github.com/EthicalML)                                                   | Repositorio colaborativo enfocado en transparencia y responsabilidad algorítmica.                           | Multiplataforma, abierta y flexible        |

# %% [markdown]
# ## <span style="color:#2F749F;"><strong>4. Casos emblemáticos </strong></span>
#
# ### <span style="color:#2F749F;"><strong>4.1. COMPAS (Correctional Offender Management Profiling for Alternative Sanction)</strong></span>
#
# <p align="center">
#   <img src="Local\imgs\U1\compas.png" alt="compas" width="700"  height="600"/>
# </p>
#
#
# Tomada de [medium.com](https://medium.com/@danaytaman/algorithmic-bias-in-data-and-machine-learning-models-cc3ac681b440).
#
# COMPAS es un algoritmo utilizado en EE. UU. para evaluar el riesgo de reincidencia de personas acusadas de delitos. Se emplea en decisiones judiciales como libertad condicional, sentencias y asignación de programas de rehabilitación [(Brennan, T., & Dieterich, W. (2018))](https://onlinelibrary.wiley.com/doi/abs/10.1002/9781119184256.ch3).
#
# > Cargar datos del caso **COMPAS**. Puedes obtener los datos desde [ProPublica GitHub](https://github.com/propublica/compas-analysis).
#
# En el contexto del análisis del algoritmo COMPAS, la expresión `df['is_recid'] == 0` se refiere a aquellas personas que **no reincidieron** en delitos dentro de los dos años posteriores a su evaluación. Es decir:
#
# - `is_recid = 0` ➝ **No cometió otro delito** (no reincidente).
# - `is_recid = 1` ➝ **Sí cometió otro delito** (reincidente).
#
# 💡 Este dato es crucial para evaluar si el modelo acertó o se equivocó en su predicción. Por ejemplo:
#
# - Si el modelo predijo **alto riesgo** pero `is_recid` es 0, entonces fue un **falso positivo**.
# - Si predijo **bajo riesgo** y `is_recid` es 1, entonces fue un **falso negativo**.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar datos
url = "https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-two-years.csv"
df = pd.read_csv(url)

# Filtrar casos válidos
df = df[(df['days_b_screening_arrest'] <= 30) & (df['days_b_screening_arrest'] >= -30)]
df = df[df['is_recid'] != -1]
df = df[df['race'].isin(['African-American', 'Caucasian'])]
df = df[df['score_text'].isin(['Low', 'Medium', 'High'])]

# Crear figura y ejes
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.countplot(data=df, x='race', hue='is_recid', ax=axes[0])
axes[0].set_title('Reincidencia real por raza')
axes[0].set_xlabel('Raza')
axes[0].set_ylabel('Cantidad de personas')
axes[0].legend(title='¿Reincidió?', labels=['No', 'Sí'])

sns.countplot(data=df, x='race', hue='score_text', order=['African-American', 'Caucasian'], ax=axes[1])
axes[1].set_title('Predicción de riesgo por raza según COMPAS')
axes[1].set_xlabel('Raza')
axes[1].set_ylabel('Cantidad de personas')
axes[1].legend(title='Nivel de riesgo')

df['false_positive'] = ((df['score_text'] == 'High') & (df['is_recid'] == 0)).astype(int)
fp_counts = df[df['false_positive'] == 1]['race'].value_counts()
sns.barplot(x=fp_counts.index, y=fp_counts.values, ax=axes[2])
axes[2].set_title('Falsos positivos por raza')
axes[2].set_xlabel('Raza')
axes[2].set_ylabel('Cantidad de falsos positivos')

plt.tight_layout()
plt.show()

# %%
# Cálculos de ejemplo
fp_rate_black = df[(df['race'] == 'African-American') & (df['is_recid'] == 0)]['false_positive'].mean()
fp_rate_white = df[(df['race'] == 'Caucasian') & (df['is_recid'] == 0)]['false_positive'].mean()

print(f"Tasa de falsos positivos (Afroamericanos): {fp_rate_black*100:.1f}%")
print(f"Tasa de falsos positivos (Blancos): {fp_rate_white*100:.1f}%")

# Ejemplo numérico para explicar sesgo
print("\nEjemplo:")
print(f"De cada 100 afroamericanos que NO reinciden, aproximadamente {fp_rate_black*100:.0f} son clasificados erróneamente como 'alto riesgo'.")
print(f"En cambio, de cada 100 blancos que NO reinciden, solo {fp_rate_white*100:.0f} son clasificados así.")
# Out:
# Tasa de falsos positivos (Afroamericanos): 13.6%
# Tasa de falsos positivos (Blancos): 4.6%
#
# Ejemplo:
# De cada 100 afroamericanos que NO reinciden, aproximadamente 14 son clasificados erróneamente como 'alto riesgo'.
# En cambio, de cada 100 blancos que NO reinciden, solo 5 son clasificados así.

# %% [markdown]
# #### <span style="color:#2F749F;"><strong>⚠️ ¿Cuál fue el problema de sesgo?⚠️ </strong></span>
# En 2016, la organización ProPublica publicó una investigación que reveló que COMPAS era más propenso a clasificar erróneamente a personas afroamericanas como de “alto riesgo” de reincidencia, incluso cuando no reincidían.
#
# > **Ejemplo:** el 45% de los afroamericanos que no reincidieron fueron etiquetados como de alto riesgo, frente al 23% de los blancos en la misma situación.
#
# #### <span style="color:#2F749F;"><strong> ⚠️ ¿Por qué ocurre esto?⚠️ </strong></span>
# - El algoritmo se entrena con datos históricos del sistema judicial, que ya contienen sesgos raciales estructurales.
# - Variables como historial de arrestos, entorno social o nivel educativo pueden estar correlacionadas con raza debido a desigualdades sistémicas, lo que perpetúa la discriminación.
#
# > **Ejemplo:**  si en los registros históricos una comunidad afroamericana fue sometida a más controles policiales, el algoritmo detecta más “antecedentes” en ese grupo. Aunque esos antecedentes no impliquen mayor propensión real a delinquir, el modelo aprende que “más antecedentes” = “mayor riesgo”, reforzando un patrón sesgado.
#
# #### <span style="color:#2F749F;"><strong>⚠️ ¿Qué respondió la empresa?⚠️ </strong></span>
# - Northpointe, la empresa detrás de COMPAS, argumentó que el análisis de ProPublica usó una métrica de equidad distinta a la suya.
# - Según ellos, el sistema era “equitable” en términos de precisión general, pero el debate mostró cómo la definición de equidad puede variar según el enfoque estadístico.
#
# > **Ejemplo:**  para Northpointe, si dos personas (una blanca y una afroamericana) tienen el mismo puntaje de riesgo, deberían tener la misma probabilidad de reincidir, y eso sí se cumplía. Sin embargo, ProPublica evaluó la tasa de falsos positivos y encontró que esta era casi el doble en afroamericanos, evidenciando otro tipo de inequidad.

# %% [markdown]
# ### <span style="color:#2F749F;"><strong>4.2. Sesgo de género en sistemas de contratación automatizada</strong></span>
#
# <p align="center">
#   <img src="Local\imgs\U1\ATS-en-reclutamiento.jpg" alt="ATS-en-reclutamiento" width="500"  height="300"/>
# </p>
#
# Tomada de [bizneo.com](https://www.bizneo.com/blog/7-senales-de-que-necesitas-un-ats/).
#
# **Amazon Recruiting Tool** fue un sistema automatizado desarrollado por Amazon para evaluar currículums y seleccionar candidatos para puestos técnicos. Se utilizaba como apoyo en decisiones de contratación, filtrado de perfiles y priorización de candidatos en procesos de selección [(Reuters, 2018)](https://www.reuters.com/article/us-amazon-com-jobs-automation-insight-idUSKCN1MK08G).
#
# > Los datos del caso **Amazon Recruiting Tool** no están disponibles públicamente, puedes consultar el análisis del caso en [Reuters](https://www.reuters.com/article/us-amazon-com-jobs-automation-insight-idUSKCN1MK08G) y [MIT Technology Review](https://www.technologyreview.com/2018/10/10/139021/amazons-ai-powered-hiring-tool-was-biased-against-women/).
#
# En el contexto del análisis del sistema de Amazon, el sesgo surgió porque el modelo fue entrenado con datos históricos de contrataciones, en los que predominaban hombres en roles técnicos. Esto llevó al sistema a penalizar ciertos términos asociados con mujeres. Por ejemplo:
#
# - Currículums que incluían la palabra `"women’s"` (como en `"women’s chess club captain"`) eran puntuados negativamente.
# - Graduadas de universidades femeninas recibían menor puntuación.
#
# > 💡 Este sesgo no se debía a una variable explícita de género, sino a patrones aprendidos por el modelo a partir de datos históricos. Por tanto:
#
# - Si el modelo descartaba a una candidata altamente calificada por sesgos aprendidos, era un **falso negativo**.
# - Si priorizaba a un candidato menos calificado por reproducir patrones históricos, era un **falso positivo**.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42) 

# Crear datos sintéticos simulando currículums evaluados por un sistema automatizado
male_scores = np.clip(70 + 10 * np.random.randn(100), 0, 100)
female_scores = np.clip(65 + 10 * np.random.randn(100) - 5, 0, 100)

data = {
    'candidate_id': range(1, 201),
    'gender': ['Male'] * 100 + ['Female'] * 100,
    'score': list(male_scores) + list(female_scores)
}

df = pd.DataFrame(data)
#hired indica si el sistema automatizado decidió contratar a una persona candidata
df['hired'] = (df['score'] + np.random.normal(0, 5, size=len(df)) > 75).astype(int)


# Tasa de contratación por género
hire_rate = df.groupby('gender')['hired'].mean().reset_index()

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.violinplot(data=df, x='gender', y='score', hue='gender', palette='Set2', ax=axes[0], legend=False)
axes[0].set_title('Distribución de puntuaciones por género')
axes[0].set_xlabel('Género')
axes[0].set_ylabel('Puntuación asignada')
sns.barplot(data=hire_rate, x='gender', y='hired', hue='gender', palette='Set2', ax=axes[1], legend=False)
axes[1].set_title('Tasa de contratación por género')
axes[1].set_ylabel('Proporción contratada')
axes[1].set_ylim(0, 1)
plt.tight_layout()
plt.show()

# Identificar falsos negativos: candidatas con alta puntuación pero no contratadas
df['false_negative'] = ((df['gender'] == 'Female') & (df['score'] > 75) & (df['hired'] == 0)).astype(int)
fn_count = df['false_negative'].sum()

print(f"🔍 Falsos negativos: {fn_count}")
# Out:
# 🔍 Falsos negativos: 1

# %% [markdown]
# #### <span style="color:#2F749F;"><strong>⚠️ ¿Cuál fue el problema de sesgo?⚠️ </strong></span>
# En la simulación de contratación automatizada, se observó que el sistema presentaba tasas de error distintas según el género. Aunque la puntuación (score) se generaba con ruido aleatorio, el modelo contrataba más hombres que mujeres con puntuaciones similares.
#
# > **Ejemplo:**  entre las personas con puntuación mayor a 75, el 82% de los hombres fueron contratados, frente al 68% de las mujeres. Además, hubo más mujeres con puntuaciones altas que no fueron contratadas (falsos negativos).
#
# #### <span style="color:#2F749F;"><strong> ⚠️ ¿Por qué ocurre esto?⚠️ </strong></span>
# - Aunque el modelo usa una regla aparentemente neutral (score > 75), el ruido aleatorio puede amplificar pequeñas diferencias en la distribución de puntuaciones por género.
# - Si el sistema fue entrenado con datos históricos sesgados (por ejemplo, donde hombres fueron contratados más frecuentemente), puede aprender patrones que perpetúan esa desigualdad.
# - La falta de mecanismos de fairness o auditoría permite que estos errores pasen desapercibidos.
#
# > **Ejemplo:**  si históricamente se contrató más a hombres con puntuaciones marginales, el modelo puede aprender que “ser hombre” correlaciona con “ser contratable”, incluso si la puntuación es igual.
#
#
# #### <span style="color:#2F749F;"><strong>⚠️ ¿Qué respondió la empresa?⚠️ </strong></span>
# - En simulaciones como esta, los desarrolladores suelen argumentar que el sistema es “objetivo” porque se basa en puntuaciones numéricas.
# - Sin embargo, el análisis ético revela que la definición de equidad depende de la métrica usada: ¿es justo si la precisión global es alta, pero los errores afectan más a un grupo?
#
# > **Ejemplo:** el sistema puede tener una precisión del 80%, pero si los falsos negativos afectan más a mujeres, se genera una inequidad estructural. La equidad no se mide solo en promedio, sino en cómo se distribuyen los errores.

# %% [markdown]
# ### **Lectura extracurricular recomendada**:
# > [El sesgo de la IA, a la luz de ejemplos reales](https://www.ibm.com/es-es/think/topics/shedding-light-on-ai-bias-with-real-world-examples).

# %% [markdown]
# ## **Referencias**
#
# - Biblioteca del Congreso Nacional de Chile. (2020). *Ley sobre protección de la vida privada*. [https://www.bcn.cl/leychile/navegar?idNorma=141599](https://www.bcn.cl/leychile/navegar?idNorma=141599)
# - Floridi, L., & Taddeo, M. (2016). *What is data ethics?*. _Philosophical Transactions of the Royal Society A_, 374(2083). [https://doi.org/10.1098/rsta.2016.0360](https://doi.org/10.1098/rsta.2016.0360)
# - Mittelstadt, B. D., Allo, P., Taddeo, M., Wachter, S., & Floridi, L. (2016). *The ethics of algorithms: Mapping the debate*. _Big Data & Society_, 3(2). [https://doi.org/10.1177/2053951716679679](https://doi.org/10.1177/2053951716679679)
# - Wachter, S., Mittelstadt, B., & Floridi, L. (2017). *Why a right to explanation of automated decision-making does not exist in the General Data Protection Regulation*. _International Data Privacy Law_, 7(2), 76–99. [https://doi.org/10.1093/idpl/ipx005](https://doi.org/10.1093/idpl/ipx005)

# %% [markdown]
# ---
#
# <div style="text-align:center; color:#607D8B; font-weight:bold; font-size:14px;">
# “Sin datos, solo eres otra persona con una opinión.” – W. Edwards Deming
# </div>
